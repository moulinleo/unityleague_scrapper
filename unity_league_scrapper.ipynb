# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd

BASE_URL = "https://unityleague.gg"
LEADERBOARD_URL = f"{BASE_URL}/ranking/eu2025/BE/?showAll=true"

def get_soup_from_url(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"[ERROR] Failed to fetch {url} - Status code: {response.status_code}")
        return None
    return BeautifulSoup(response.text, 'html.parser')

def extract_players(soup):
    print("[INFO] Extracting players from leaderboard...")
    players = []
    rows = soup.select("table#rankingTable tbody tr")
    print(f"[DEBUG] Found {len(rows)} player rows in leaderboard")
    for row in rows:
        cols = row.find_all("td")
        if len(cols) < 3:
            print("[WARN] Skipping malformed row with insufficient columns")
            continue
        rank = cols[0].get_text(strip=True)
        points = int(cols[1].get_text(strip=True))
        player_tag = cols[2].find("a")
        if not player_tag:
            print("[WARN] No player link found in row")
            continue
        name = player_tag.get_text(strip=True)
        profile_url = BASE_URL + player_tag['href']
        player_id = player_tag['href'].split('/')[2]
        players.append({
            "rank": rank,
            "points": points,
            "name": name,
            "profile_url": profile_url,
            "player_id": player_id
        })
    return players

def parse_player_profile(url):
    soup = get_soup_from_url(url)
    if not soup:
        return None

    # 🎯 Find the "Performance per format" table using its heading
    perf_heading = soup.find("h3", string=re.compile("Performance per format", re.I))
    if not perf_heading:
        print("[WARN] 'Performance per format' heading not found.")
        return None

    perf_table = perf_heading.find_next("table")
    if not perf_table:
        print("[WARN] No table found under 'Performance per format'")
        return None

    # Find Limited row
    rows = perf_table.select("tbody tr")
    limited_row = next((r for r in rows if "Limited" in r.get_text()), None)
    if not limited_row:
        print("[INFO] No Limited format data found, skipping player.")
        return None

    columns = limited_row.find_all("td")
    record_text = columns[1].text.strip()
    winrate = columns[2].text.strip()
    wins, losses, *_ = map(int, re.findall(r"\d+", record_text))
    print(f"[DEBUG] Limited Record: {record_text} -> Wins: {wins}, Losses: {losses}, Winrate: {winrate}")

    # 🎯 Extract Limited events only from event history
    try:
        events_section = soup.find("h2", string=re.compile("Event history", re.I)).find_next("table")
        event_rows = events_section.find_all("tr")[1:]
        limited_events = [r for r in event_rows if "Limited" in r.text and "draft" in r.text.lower()]
        print(f"[DEBUG] Found {len(limited_events)} Limited Draft events")
    except Exception as e:
        print(f"[ERROR] Failed to parse event history: {e}")
        limited_events = []

    return {
        "wins": wins,
        "losses": losses,
        "winrate": winrate,
        "limited_events": len(limited_events),
        "matches": wins + losses
    }

def main():
    print("[START] Scraping Unity League Limited Draft Leaderboard")
    leaderboard_soup = get_soup_from_url(LEADERBOARD_URL)
    if not leaderboard_soup:
        print("[FATAL] Could not load leaderboard page.")
        return

    players = extract_players(leaderboard_soup)
    results = []

    for player in players[0:40]:
        print(f"[INFO] Processing {player['name']} ({player['profile_url']})")
        try:
            stats = parse_player_profile(player['profile_url'])
            if stats:
                player.update(stats)
                results.append(player)
            else:
                print(f"[SKIP] No Limited results for {player['name']}")
        except Exception as e:
            print(f"[ERROR] Exception while processing {player['name']}: {e}")
        time.sleep(1)  # Be polite to the server

    print("\n[RESULTS] Players with Limited format stats:")
    for p in results:
        print(f"{p['rank']}. {p['name']} - {p['points']} pts - "
              f"{p['wins']}W/{p['losses']}L - {p['winrate']} over {p['limited_events']} Limited events")
    return results


if __name__ == "__main__":
    results = main()
# Out:
# [START] Scraping Unity League Limited Draft Leaderboard
# [INFO] Fetching URL: https://unityleague.gg/ranking/eu2025/BE/?showAll=true
# [SUCCESS] Fetched https://unityleague.gg/ranking/eu2025/BE/?showAll=true
# [INFO] Extracting players from leaderboard...
# [DEBUG] Found 304 player rows in leaderboard
# [INFO] Processing Nicolas Prail (https://unityleague.gg/player/3681/)
# [INFO] Parsing player profile: https://unityleague.gg/player/3681/
# [INFO] Fetching URL: https://unityleague.gg/player/3681/
# [SUCCESS] Fetched https://unityleague.gg/player/3681/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Nicolas Prail
# [INFO] Processing Ignacio J. Garcia S. (https://unityleague.gg/player/16227/)
# [INFO] Parsing player profile: https://unityleague.gg/player/16227/
# [INFO] Fetching URL: https://unityleague.gg/player/16227/
# [SUCCESS] Fetched https://unityleague.gg/player/16227/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Ignacio J. Garcia S.
# [INFO] Processing Arthur Brocsko (https://unityleague.gg/player/9244/)
# [INFO] Parsing player profile: https://unityleague.gg/player/9244/
# [INFO] Fetching URL: https://unityleague.gg/player/9244/
# [SUCCESS] Fetched https://unityleague.gg/player/9244/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Arthur Brocsko
# [INFO] Processing Deimas (https://unityleague.gg/player/10274/)
# [INFO] Parsing player profile: https://unityleague.gg/player/10274/
# [INFO] Fetching URL: https://unityleague.gg/player/10274/
# [SUCCESS] Fetched https://unityleague.gg/player/10274/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Deimas
# [INFO] Processing Amand Dosimont (https://unityleague.gg/player/3773/)
# [INFO] Parsing player profile: https://unityleague.gg/player/3773/
# [INFO] Fetching URL: https://unityleague.gg/player/3773/
# [SUCCESS] Fetched https://unityleague.gg/player/3773/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Amand Dosimont
# [INFO] Processing Dirty Haribo (https://unityleague.gg/player/3539/)
# [INFO] Parsing player profile: https://unityleague.gg/player/3539/
# [INFO] Fetching URL: https://unityleague.gg/player/3539/
# [SUCCESS] Fetched https://unityleague.gg/player/3539/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Dirty Haribo
# [INFO] Processing Serket (https://unityleague.gg/player/4427/)
# [INFO] Parsing player profile: https://unityleague.gg/player/4427/
# [INFO] Fetching URL: https://unityleague.gg/player/4427/
# [SUCCESS] Fetched https://unityleague.gg/player/4427/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Serket
# [INFO] Processing Tranzmaster (https://unityleague.gg/player/3557/)
# [INFO] Parsing player profile: https://unityleague.gg/player/3557/
# [INFO] Fetching URL: https://unityleague.gg/player/3557/
# [SUCCESS] Fetched https://unityleague.gg/player/3557/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Tranzmaster
# [INFO] Processing Aymeric Steinbach (https://unityleague.gg/player/11248/)
# [INFO] Parsing player profile: https://unityleague.gg/player/

# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Pierre Glesner
# [INFO] Processing Levioloniste Virtuose (https://unityleague.gg/player/11225/)
# [INFO] Parsing player profile: https://unityleague.gg/player/11225/
# [INFO] Fetching URL: https://unityleague.gg/player/11225/
# [SUCCESS] Fetched https://unityleague.gg/player/11225/
# [DEBUG] Limited Record: 17 - 12 - 0 -> Wins: 17, Losses: 12, Winrate: 58.6%
# [DEBUG] Found 7 Limited Draft events
# [INFO] Processing Alexandre Mairesse (https://unityleague.gg/player/16013/)
# [INFO] Parsing player profile: https://unityleague.gg/player/16013/
# [INFO] Fetching URL: https://unityleague.gg/player/16013/
# [SUCCESS] Fetched https://unityleague.gg/player/16013/
# [INFO] No Limited format data found, skipping player.
# [SKIP] No Limited results for Alexandre Mairesse
# [INFO] Processing Laurent Poliakoff (https://unityleague.gg/player/11244/)
# [INFO] Parsing player profile: https://unityleague.gg/player/11244/
# [INFO] Fetching URL: https://unityleague.gg/player/11244/
# [SUCCESS] Fetched https://unityleague.gg/player/11244/
# [DEBUG] Limited Record: 17 - 6 - 1 -> Wins: 17, Losses: 6, Winrate: 70.8%
# [DEBUG] Found 8 Limited Draft events
# [INFO] Processing Raimundo Diz (https://unityleague.gg/player/12269/)
# [INFO] Parsing player profile: https://unityleague.gg/player/12269/
# [INFO] Fetching URL: https://unityleague.gg/player/12269/
# [SUCCESS] Fetched https://unityleague.gg/player/12269/
# [DEBUG] Limited Record: 13 - 4 - 2 -> Wins: 13, Losses: 4, Winrate: 68.4%
# [DEBUG] Found 5 Limited Draft events
#
# [RESULTS] Players with Limited format stats:
# 9. Aymeric Steinbach - 266 pts - 30W/17L - 63.8% over 13 Limited events
# 10. Thomas Bijl - 246 pts - 18W/13L - 58.1% over 9 Limited events
# 12. Thomas Decamp - 226 pts - 27W/19L - 58.7% over 10 Limited events
# 16. Maxime, dit le BG, Corchia - 189 pts - 7W/0L - 100.0% over 0 Limited events
# 17. Niels Lucking - 165 pts - 12W/5L - 70.6% over 3 Limited events
# 18. Emmanuel Fleau De Frôler - 160 pts - 8W/3L - 72.7% over 1 Limited events
# 19. Ricardo R - 154 pts - 17W/12L - 58.6% over 7 Limited events
# 21. Nicolas Sargos - 146 pts - 30W/8L - 73.2% over 11 Limited events
# 22. Martin Alberty - 127 pts - 3W/4L - 42.9% over 0 Limited events
# 23. Maciej Mrozowski - 122 pts - 25W/14L - 61.0% over 11 Limited events
# 24. Martin Lepeintre - 122 pts - 20W/11L - 62.5% over 8 Limited events
# 25. Pierrick Decamp - 120 pts - 9W/14L - 33.3% over 5 Limited events
# 26. Pierre Delandsheere - 109 pts - 5W/1L - 83.3% over 2 Limited events
# 28. Vincent Bichelberger - 108 pts - 22W/10L - 68.8% over 8 Limited events
# 31. Ozan Fincan - 91 pts - 16W/10L - 59.3% over 8 Limited events
# 33. Arthur Coenen - 88 pts - 5W/18L - 20.0% over 6 Limited events
# 35. Thomas de Brito - 81 pts - 11W/8L - 57.9% over 4 Limited events
# 37. Levioloniste Virtuose - 78 pts - 17W/12L - 58.6% over 7 Limited events
# 39. Laurent Poliakoff - 76 pts - 17W/6L - 70.8% over 8 Limited events
# 40. Raimundo Diz - 73 pts - 13W/4L - 68.4% over 5 Limited events

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#    rank  points                        name  \
# 0     9     266           Aymeric Steinbach
# 1    10     246                 Thomas Bijl
# 2    12     226               Thomas Decamp
# 3    16     189  Maxime, dit le BG, Corchia
# 4    17     165               Niels Lucking
# 5    18     160    Emmanuel Fleau De Frôler
# 6    19     154                   Ricardo R
# 7    21     146              Nicolas Sargos
# 8    22     127              Martin Alberty
# 9    23     122            Maciej Mrozowski
# 10   24     122            Martin Lepeintre
# 11   25     120             Pierrick Decamp
# 12   26     109         Pierre Delandsheere
# 13   28     108        Vincent Bichelberger
# 14   31      91                 Ozan Fincan
# 15   33      88               Arthur Coenen
# 16   35      81             Thomas de Brito
# 17   37      78       Levioloniste Virtuose
# 18   39      76           Laurent Poliakoff
# 19   40      73                Raimundo Diz
#
#                              profile_url player_id  wins  losses winrate  \
# 0   https://unityleague.gg/player/11248/     11248    30      17   63.8%
# 1   https://unityleague.gg/player/11219/     11219    18      13   58.1%
# 2   https://unityleague.gg/player/11230/     11230    27      19   58.7%
# 3   https://unityleague.gg/player/11211/     11211     7       0  100.0%
# 4   https://unityleague.gg/player/11255/     11255    12       5   70.6%
# 5   https://unityleague.gg/player/11215/     11215     8       3   72.7%
# 6   https://unityleague.gg/player/11259/     11259    17      12   58.6%
# 7   https://unityleague.gg/player/11223/     11223    30       8   73.2%
# 8   https://unityleague.gg/player/11217/     11217     3       4   42.9%
# 9   https://unityleague.gg/player/11224/     11224    25      14   61.0%
# 10  https://unityleague.gg/player/11250/     11250    20      11   62.5%
# 11  https://unityleague.gg/player/12841/     12841     9      14   33.3%
# 12  https://unityleague.gg/player/11218/     11218     5       1   83.3%
# 13  https://unityleague.gg/player/11227/     11227    22      10   68.8%
# 14  https://unityleague.gg/player/12822/     12822    16      10   59.3%
# 15  https://unityleague.gg/player/11220/     11220     5      18   20.0%
# 16  https://unityleague.gg/player/13948/     13948    11       8   57.9%
# 17  https://unityleague.gg/player/11225/     11225    17      12   58.6%
# 18  https://unityleague.gg/player/11244/     11244    17       6   70.8%
# 19  https://unityleague.gg/player/12269/     12269    13       4   68.4%
#
#     limited_events  matches
# 0               13       47
# 1                9       31
# 2               10       46
# 3                0        7
# 4                3       17
# 5                1       11
# 6                7       29
# 7               11       38
# 8                0        7
# 9               11       39
# 10               8       31
# 11               5       23
# 12               2        6
# 13               8       32
# 14               8       26
# 15               6       23
# 16               4       19
# 17               7       29
# 18               8       23
# 19               5       17
